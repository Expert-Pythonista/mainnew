# %% [markdown]
# <a href="https://colab.research.google.com/github/Expert-Pythonista/mainnew/blob/studt/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Hi=456
"Bye"
# Out:
# 'Bye'

# %%
!

# %%
""
# Out:
# ''
